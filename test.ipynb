# %%
import pandas as pd

parquet_file_path = '/Users/eeyoontaek/Desktop/backpack_test/output/ecommerce_parquet/event_date=2019-10-03/'

df = pd.read_parquet(parquet_file_path, engine='pyarrow')

df_sorted = df.sort_values(by='event_time', ascending=True)
df_sorted.tail()
# Out:
#                       event_time event_type product_id          category_id  \
# 1166448  2019-10-03 05:59:59 UTC       view   11900000  2084217994270999025
# 1166447  2019-10-03 05:59:59 UTC       view   22700078  2053013556168753601
# 1166460  2019-10-03 05:59:59 UTC       view   16200316  2053013556344914381
# 1166453  2019-10-03 05:59:59 UTC       view    1004775  2053013555631882655
# 1166461  2019-10-03 05:59:59 UTC       view    1306532  2053013558920217191
#
#                   category_code    brand   price    user_id  \
# 1166448                    None     None  115.83  555237422
# 1166447                    None    stels  180.18  541648026
# 1166460       kids.fmcg.diapers  huggies   19.92  513197973
# 1166453  electronics.smartphone   xiaomi  180.96  542176885
# 1166461      computers.notebook       hp  540.30  555368310
#
#                                  user_session      event_time_kst
# 1166448  bea04c95-1a99-42d9-9ada-2db64032867e 2019-10-03 14:59:59
# ...
